# %% [markdown]
# # LAB 1
# # 2.1 Experiment: Optical Imager

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
# ## 2.1.1: Plate Scale (Ronchi Mask Resolution)
#
# #### Determine an optimal imaging system with a plate scale that would allow to resolve two successive lines of the provided Ronchi mask.
#
#
# ### Lens Setup 1:
# - **Camera → Lens #2 (75 mm) → Lens #3 (100 mm) → Ronchi Mask**
#
# ### Explanation of Lens Placement:
# - **Distance between lenses**: The lenses should be placed as close as possible to each other to minimize the effect of light divergence or convergence.
# - **Distance from the camera**: The **75 mm lens** should be placed about **1-2 focal lengths** away from the camera. The object (Ronchi mask) should be placed far away on the optical breadboard to simulate an object at infinity.
#
# ### Magnification:
# For an object at infinity, the magnification \(M\) is calculated as the ratio of the focal lengths:
# $$
# M = \frac{f_2}{f_1}
# $$
# Where:
# - $f_1 = 75 \, \text{mm}$ (first lens)
# - $f_2 = 100 \, \text{mm}$ (second lens)
#
#
# ### Effective Focal Length (EFL):
# The combined **effective focal length** (EFL) of the two lenses is calculated using the thin lens equation:
# $$
# \frac{1}{\text{EFL}} = \frac{1}{f_1} + \frac{1}{f_2}
# $$
#
# ### Plate Scale:
# The plate scale is calculated as:
# $$
# \text{Plate Scale (arcseconds/pixel)} = \frac{206,265}{\text{EFL}} \times \text{Pixel Size (mm)}
# $$
# Where:
# - Pixel size of the Blackfly camera = 2.4 µm = 0.0024 mm
#
# #### Summary for 2.1.1 (Setup 1):
#
# - Effective Focal Length (EFL): 42.86 mm
# - Magnification: 1.33x
# - Plate Scale: 11.55 arcseconds/pixel
# - Distance from Camera to Lens #2 (75 mm): 75 mm
# - Distance between Lens #2 and Lens #3: 10 mm
# - Ronchi Mask: Far from the system (acting as an object at infinity).
#
# -----------------------------------------------------------------------------------------------------------
#
# ### Lens Setup 2:
# - **Camera → Lens #1 (50 mm) → Lens #3 (100 mm) → Ronchi Mask**
#
# ### Explanation of Lens Placement:
# - **Distance between lenses**: The lenses should be placed as close as possible to each other to minimize the effect of light divergence or convergence.
# - **Distance from the camera**: The **50 mm lens** should be placed about **1-2 focal lengths** away from the camera. The object (Ronchi mask) should be placed far away on the optical breadboard to simulate an object at infinity.
#
# ### Magnification:
# For an object at infinity, the magnification \(M\) is calculated as the ratio of the focal lengths:
# $$
# M = \frac{f_2}{f_1}
# $$
# Where:
# - $f_1 = 50 \, \text{mm}$ (first lens)
# - $f_2 = 100 \, \text{mm}$ (second lens)
#
#
# ### Effective Focal Length (EFL):
# The combined **effective focal length** (EFL) of the two lenses is calculated using the thin lens equation:
# $$
# \frac{1}{\text{EFL}} = \frac{1}{f_1} + \frac{1}{f_2}
# $$
#
# ### Plate Scale:
# The plate scale is calculated as:
# $$
# \text{Plate Scale (arcseconds/pixel)} = \frac{206,265}{\text{EFL}} \times \text{Pixel Size (mm)}
# $$
# Where:
# - Pixel size of the Blackfly camera = 2.4 µm = 0.0024 mm
#
# #### Summary for 2.1.1:
#
# - Effective Focal Length (EFL): 33.3 mm
# - Magnification: 2x
# - Plate Scale: 14.89 arcseconds/pixel
# - Distance from Camera to Lens #2 (50 mm): 100 mm
# - Distance between Lens #2 and Lens #3: 30 mm
# - Ronchi Mask: ~50mm away from lens #3
#
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
#
# ## 2.1.2: Field of View (Imaging Jupiter)
# #### Determine an optimal imaging system that is capable of imaging the entire extent of Jupiter in a single exposure.
#
#
# ### Lens Setup:
# - **Camera → Lens #1 (50 mm) → Jupiter Image**
#
# ### Explanation of Lens Placement:
# - **Distance between lens and Camera**: Place the **lenses ~35mm from the detector**.
# - **Distance from Jupiter**: The object (Jupiter image card) should be placed far away on the optical breadboard to simulate an object at infinity.
#
#
# ### Effective Focal Length (EFL):
# The effective focal length is calculated using the thin lens equation:
# $$
# \frac{1}{\text{EFL}} = \frac{1}{f_1}
# $$
#
# ### Field of View (FOV):
# The field of view is calculated as:
# $$
# \text{FOV (degrees)} = 2 \times \arctan\left(\frac{\text{Sensor Dimension (mm)}}{2 \times \text{EFL (mm)}}\right)
# $$
# Where:
# - Sensor width of the Blackfly camera = 7.37 m
#
# #### Summary for 2.1.2:
#
# - Effective Focal Length (EFL): 50 mm
# - Magnification: N/A
# - Field of View (FOV): 8.44°
# - Distance from Camera to Lens #1 (50 mm): 35 mm
# - Jupiter: Far from the system (acting as an object at infinity).
#
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
#
# ## 2.1.3: Field of View & Plate Scale (Resolving Jupiter's Red Spot)
#
# ### Our Final Lens Setup:
# - **Camera → Lens #2 (75 mm) → Lens #3 (100 mm) → Jupiter Image**
#
# ### Explanation of Lens Placement:
# - **Distance between lenses**: The lenses should be placed at about **~55mm apart**. The 75mm lens should be as close to the camera as possible.
# - **Distance from the camera**: The object (Jupiter or globular cluster image) should be placed far away to simulate an object at infinity.
#
# ### Magnification:
# The magnification \(M\) is:
# $$
# M = \frac{f_2}{f_1} = \frac{100}{75} = 1.33
# $$
#
# ### Effective Focal Length (EFL):
# The combined effective focal length is:
# $$
# \frac{1}{\text{EFL}} = \frac{1}{f_1} + \frac{1}{f_2} = \frac{1}{75} + \frac{1}{100} = 42.86
# $$
#
# ### Plate Scale:
# The plate scale is:
# $$
# \text{Plate Scale (arcseconds/pixel)} = \frac{206,265}{\text{EFL}} \times \text{Pixel Size (mm)} = 11.55\frac{arcseconds}{pixel}
# $$
#
# ### Field of View (FOV):
# The field of view is:
# $$
# \text{FOV (degrees)} = 2 \times \arctan\left(\frac{\text{Sensor Dimension (mm)}}{2 \times \text{EFL (mm)}}\right) = 9.8°
# $$
#
#
# #### Summary for 2.1.3:
#
# - Effective Focal Length (EFL): 42.86 mm
# - Magnification: 1.33x
# - Field of View (FOV): 9.8°
# - Plate Scale: 11.55 arcseconds/pixel
# - Distance from Camera to Lens #2 (75 mm): ~15 mm
# - Distance between Lens #2 and Lens #3: ~55 mm
# - Jupiter: Far from the system (acting as an object at infinity).
#
# ----------------------------------

# %% [markdown]
# ### Why the 75 mm and 100 mm Setup Works?
#
# - The 75 mm and 100 mm setup provides a magnification of 1.33x, which is a reasonable level to resolve details on Jupiter, such as the red spot.
# - The effective focal length (42.86 mm) and field of view (9.8°) in this configuration gives a balance between providing sufficient resolution and capturing enough of Jupiter in the frame.
# - The plate scale (11.55 arcseconds/pixel) gives the resolution needed to be able to detect fine features on Jupiter, while still maintaining a usable field of view.

# %% [markdown]
# ### Calculation of Plate Scale for Resolving Jupiter's Red Spot
#
# We want to calculate the plate scale required to resolve the **5 mm red spot** on the **paper Jupiter**.
#
# ### Step 1: Calculate the Angular Size of the Red Spot
#
# The angular size:
#
# $$\theta_{\text{arcseconds}} $$
#
# of an object is given by the formula:
#
#
# $$
# \theta_{\text{arcseconds}} = \frac{\text{Physical Size of Object (mm)}}{\text{Distance to Object (mm)}} \times 206,265 = \frac{5mm}{1000mm} \times 206,265 = \text{1031.33 arcseconds}
# $$
#
# Where:
# - The **physical size** of the red spot is 5 mm.
# - The **distance to the object** (paper Jupiter) is 1,000 mm (1 meter).
#
# ### Step 2: Calculate the Required Plate Scale
#
# The required plate scale to resolve the red spot over at least 2 pixels is:
#
# $$
# \text{Plate Scale (arcseconds/pixel)} = \frac{\theta_{\text{arcseconds}}}{\text{Number of Pixels}} = \frac{1031.33}{2} = \text{515.67}\frac{arcseconds}{pixels}
# $$
#
# We will assume we want the red spot to cover at least 2 pixels.
#
# ### Step 3: Compare to the Current Plate Scale
#
# The current plate scale for our optical setup (75 mm + 100 mm lenses) is calculated as:
#
# $$
# \text{Current Plate Scale} = \frac{206,265}{\text{EFL}} \times \text{Pixel Size (mm)} = 11.55 \frac{arcseconds}{pixel}
# $$
#
# Where the effective focal length (EFL) is **42.86 mm** (from the previous calculation), and the pixel size is **2.4 µm** or **0.0024 mm**. Since our plate scale is finer we are able to clearly see the Red Spot on Jupiter.

# %%
import math

# Constants
arcseconds_per_radian = 206265  # Conversion factor
pixel_size = 0.0024  # Pixel size of the camera in mm
sensor_width = 7.37  # Sensor width in mm

# 2.1.1: Plate Scale (Ronchi Mask Resolution)
f1_211 = 75  # Focal length of the first lens in mm
f2_211 = 100  # Focal length of the second lens in mm

# Effective Focal Length (EFL)
efl_211 = 1 / (1 / f1_211 + 1 / f2_211)
print(f"Effective Focal Length (EFL) for 2.1.1: {efl_211:.2f} mm")

# Plate Scale
plate_scale_211 = (arcseconds_per_radian / efl_211) * pixel_size
print(f"Plate Scale for 2.1.1: {plate_scale_211:.2f} arcseconds/pixel")

# Magnification
magnification_211 = f2_211 / f1_211
print(f"Magnification for 2.1.1: {magnification_211:.2f}")

# 2.1.2: Field of View (Imaging Jupiter)
f1_212 = 50  # Focal length of the first lens in mm
f2_212 = 75  # Focal length of the second lens in mm

# Effective Focal Length (EFL)
efl_212 = 1 / (1 / f1_212 + 1 / f2_212)
print(f"Effective Focal Length (EFL) for 2.1.2: {efl_212:.2f} mm")

# Field of View (FOV)
fov_212 = 2 * math.degrees(math.atan(sensor_width / (2 * efl_212)))
print(f"Field of View (FOV) for 2.1.2: {fov_212:.2f} degrees")

# Magnification
magnification_212 = f2_212 / f1_212
print(f"Magnification for 2.1.2: {magnification_212:.2f}")

# 2.1.3: Field of View & Plate Scale (Resolving Jupiter's Red Spot)
f1_213 = 75  # Focal length of the first lens in mm
f2_213 = 100  # Focal length of the second lens in mm

# Effective Focal Length (EFL)
efl_213 = 1 / (1 / f1_213 + 1 / f2_213)
print(f"Effective Focal Length (EFL) for 2.1.3: {efl_213:.2f} mm")

# Plate Scale
plate_scale_213 = (arcseconds_per_radian / efl_213) * pixel_size
print(f"Plate Scale for 2.1.3: {plate_scale_213:.2f} arcseconds/pixel")

# Field of View (FOV)
fov_213 = 2 * math.degrees(math.atan(sensor_width / (2 * efl_213)))
print(f"Field of View (FOV) for 2.1.3: {fov_213:.2f} degrees")

# Magnification
magnification_213 = f2_213 / f1_213
print(f"Magnification for 2.1.3: {magnification_213:.2f}")
# Out:
# Effective Focal Length (EFL) for 2.1.1: 42.86 mm
# Plate Scale for 2.1.1: 11.55 arcseconds/pixel
# Magnification for 2.1.1: 1.33
# Effective Focal Length (EFL) for 2.1.2: 30.00 mm
# Field of View (FOV) for 2.1.2: 14.01 degrees
# Magnification for 2.1.2: 1.50
# Effective Focal Length (EFL) for 2.1.3: 42.86 mm
# Plate Scale for 2.1.3: 11.55 arcseconds/pixel
# Field of View (FOV) for 2.1.3: 9.83 degrees
# Magnification for 2.1.3: 1.33

# %% [markdown]
# # 2.2 Experiment: Detector Properties

# %%
import numpy as np
from astropy.io import fits
import struct
import numpy as np
from glob import glob
import os

import matplotlib.pyplot as plt

# %matplotlib inline
def raw_to_fits(raw_file, shape=(1080, 1440), destination=None, ADC_bits=12, simu_artifacts=False):
    """
    Converts a .raw file to a FITS formatted image.
    raw_file : The file path of the raw image. Must have format of
        <prefix>_<texp>us.raw
    shape : A list or tuple with (# of rows, # of columns) for the image
    destination : an alternate destination/filename for the FITS image
       (default is to replace the .raw extension and save in the same folder)
    """
    try:
        # Extract timestamp or set a default value
        parts = raw_file.split("us.raw")[0].split("_")
        if parts and parts[-1].replace('.', '', 1).isdigit():
            tint = float(parts[-1]) / 1e6
        else:
            tint = 0  # Default value
    except (ValueError, IndexError) as e:
        print(f"Error extracting timestamp from filename '{raw_file}': {e}")
        tint = 0  # Default value or handle as appropriate

    # Get shape of image
    nrows, ncols = shape
    # Open raw file
    with open(raw_file, 'rb') as raw:
        raw_img = raw.read()
    # Check file size / format
    filesize = len(raw_img)
    if filesize == nrows * ncols:  # 8-bit
        size = 'B'
        file_bits = 8
    elif filesize == nrows * ncols * 2:  # 16-bit
        size = 'H'
        file_bits = 16
    else:  # No size match
        raise ValueError("The image shape provided does not match the length of the file")
    # Format binary string
    fmt = f"<{nrows * ncols}{size}"
    # Convert byte string to numpy array
    byte_array = np.array(struct.unpack(fmt, raw_img)).reshape(nrows, ncols)
    if file_bits > ADC_bits:
        byte_array = byte_array / 2 ** (file_bits - ADC_bits)

    if simu_artifacts:
        ny, nx = byte_array.shape

        # Adding dark
        dark_current = 1.25  # ADU/s
        byte_array += dark_current * tint

        # multiplying flat
        x_grid, y_grid = np.meshgrid(np.arange(nx), np.arange(ny))
        flat_field = np.exp(-0.5 * ((x_grid - nx // 2) ** 2 / (3 * nx) ** 2 + (y_grid - ny // 2) ** 2 / (3 * ny) ** 2))
        byte_array *= flat_field

        state = np.random.get_state()
        np.random.seed(0)

        # adding hot pixels
        hot_pix_indices = np.random.randint(0, high=nx * ny - 1, size=int(0.01 * nx * ny))
        hot_pix_indices = np.unravel_index(hot_pix_indices, (ny, nx))
        byte_array[hot_pix_indices] *= tint * np.clip(30 * np.random.randn(int(0.01 * nx * ny)), dark_current, 2 ** ADC_bits)

        # adding cold pixels
        cold_pix_indices = np.random.randint(0, high=nx * ny - 1, size=int(0.01 * nx * ny))
        cold_pix_indices = np.unravel_index(cold_pix_indices, (ny, nx))
        byte_array[cold_pix_indices] *= np.random.uniform(0, 0.5, size=int(0.01 * nx * ny))

        np.random.set_state(state)

        # Adding bias
        byte_array += 64

        # adding readnoise
        readnoise = 3  # ADU
        byte_array += readnoise * np.random.randn(ny, nx)

        byte_array = np.clip(byte_array, 0, 2 ** ADC_bits)

    # FITS file name
    if destination is None:
        fits_file = raw_file.replace('.raw', '.fits')
    else:
        fits_file = destination
    if simu_artifacts:
        fits_file = fits_file.replace(".fits", "_simu.fits")
    # Save as FITS
    hdu = fits.PrimaryHDU(byte_array)
    hdu.writeto(fits_file, overwrite=True)

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
#
# ## 2.2.1 Bias and Dark Current
#
# ### Objective:
# - Bias Level: Measure the bias level of the detector by collecting dark frames with short integration times.
# - Dark Current: Measure the dark current by collecting dark frames at varying exposure times.

# %% [markdown]
# ## Part 1: Bias

# %%
raw_files_directory = r'C:\Users\levig\Downloads\BiasFrames'
raw_files = glob(os.path.join(raw_files_directory, '*.raw'))
shape = (1616, 1240)  
for raw_file in raw_files:
    raw_to_fits(raw_file, shape=shape)
    print(f"Converted {raw_file} to FITS format.")
# Out:
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_1.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_10.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_2.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_3.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_4.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_5.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_6.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_7.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_8.raw to FITS format.
# Converted C:\Users\levig\Downloads\BiasFrames\bias_frame_9.raw to FITS format.

# %% [markdown]
# ### Plotting the Bias Frames

# %%
fits_files_directory = r'C:\Users\levig\Downloads\BiasFrames'

bias_frames = [fits.getdata(os.path.join(fits_files_directory, f'bias_frame_{i}.fits')) for i in range(1, 11)]

mean_signals = [np.mean(frame) for frame in bias_frames]

plt.hist(mean_signals, bins=20, color='blue', alpha=0.7)
plt.title("Histogram of Bias Levels")
plt.xlabel("Mean Signal (ADU)")
plt.ylabel("Frequency")
plt.show()

bias_level = np.mean(mean_signals)
bias_error = np.std(mean_signals) / np.sqrt(len(mean_signals))  # Error on the mean
print(f"Bias Level: {bias_level:.2f} ADU ± {bias_error:.2f} ADU")
# Out:
# Bias Level: 0.28 ADU ± 0.00 ADU

# %% [markdown]
# #### This histogram displays the mean signal (in ADU) of each bias frame, showing the distribution of bias levels across the 10 frames. The majority of frames have a bias level around 0.278 ADU, which indicates a consistent bias signal. The tight distribution confirms low variability in the bias measurements.

# %%
flattened_bias = np.array(bias_frames).flatten()

plt.hist(flattened_bias, bins=100, color='blue', alpha=0.7)
plt.title("Pixel-by-Pixel Histogram of Bias Levels")
plt.xlabel("Bias Signal (ADU)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### This histogram plots the distribution of bias signals for every pixel across all the frames. The data is heavily skewed toward very low bias values, which is consistent with the overall low bias level (around 0.28 ADU) observed in previous visualizations. The lack of higher ADU values confirms no extreme outliers (hot or cold pixels).

# %% [markdown]
# ## Part 2: Dark Current

# %%
raw_dcfiles_directory = r'C:\Users\levig\Downloads\DarkCurrents'
raw_dcfiles = glob(os.path.join(raw_dcfiles_directory, '*.raw'))
shape = (1616, 1240)  
for raw_dcfile in raw_dcfiles:
    raw_to_fits(raw_dcfile, shape=shape)
    print(f"Converted {raw_dcfile} to FITS format.")
# Out:
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.01 (1).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.01 (2).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.01 (3).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.01 (4).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.01 (5).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.1 (1).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.1 (2).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.1 (3).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.1 (4).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.1 (5).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.5 (1).raw to FITS format.
# Converted C:\Users\levig\Downloads\DarkCurrents\DC 0.5 (2).raw to FITS format.
# ...

# %%
from astropy.io import fits
import os
import numpy as np

fits_dcfiles_directory = r'C:\Users\levig\Downloads\DarkCurrents'

exposure_times = [0.01 ,0.1, 0.5, 1, 5, 10]  # in seconds

dc_files = {}

for exp_time in exposure_times:
    fits_data_list = []
    for i in range(1, 6):
        fits_filename = f'DC {exp_time} ({i}).fits'
        fits_file_path = os.path.join(fits_dcfiles_directory, fits_filename)
        if os.path.exists(fits_file_path):
            fits_data_list.append(fits.getdata(fits_file_path))
            print(f"Loaded {fits_filename}")
        else:
            print(f"File not found: {fits_file_path}")
    
    dc_files[f"{exp_time}s"] = fits_data_list
# Out:
# Loaded DC 0.01 (1).fits
# Loaded DC 0.01 (2).fits
# Loaded DC 0.01 (3).fits
# Loaded DC 0.01 (4).fits
# Loaded DC 0.01 (5).fits
# Loaded DC 0.1 (1).fits
# Loaded DC 0.1 (2).fits
# Loaded DC 0.1 (3).fits
# Loaded DC 0.1 (4).fits
# Loaded DC 0.1 (5).fits
# Loaded DC 0.5 (1).fits
# Loaded DC 0.5 (2).fits
# Loaded DC 0.5 (3).fits
# Loaded DC 0.5 (4).fits
# Loaded DC 0.5 (5).fits
# Loaded DC 1 (1).fits
# Loaded DC 1 (2).fits
# Loaded DC 1 (3).fits
# Loaded DC 1 (4).fits
# Loaded DC 1 (5).fits
# File not found: C:\Users\levig\Downloads\DarkCurrents\DC 5 (1).fits
# Loaded DC 5 (2).fits
# Loaded DC 5 (3).fits
# Loaded DC 5 (4).fits
# Loaded DC 5 (5).fits
# Loaded DC 10 (1).fits
# Loaded DC 10 (2).fits
# Loaded DC 10 (3).fits
# Loaded DC 10 (4).fits
# File not found: C:\Users\levig\Downloads\DarkCurrents\DC 10 (5).fits

# %%
mean_signals = []

for exp_time in exposure_times:
    fits_data_list = dc_files[f"{exp_time}s"]
    mean_signal_per_exp_time = np.mean([np.mean(fits_data) for fits_data in fits_data_list])
    mean_signals.append(mean_signal_per_exp_time)
for exp_time, mean_signal in zip(exposure_times, mean_signals):
    print(f"Exposure Time: {exp_time} s, Mean Signal: {mean_signal:.2f} ADU")
# Out:
# Exposure Time: 0.01 s, Mean Signal: 0.27 ADU
# Exposure Time: 0.1 s, Mean Signal: 0.36 ADU
# Exposure Time: 0.5 s, Mean Signal: 0.90 ADU
# Exposure Time: 1 s, Mean Signal: 1.77 ADU
# Exposure Time: 5 s, Mean Signal: 8.15 ADU
# Exposure Time: 10 s, Mean Signal: 16.86 ADU

# %%
import matplotlib.pyplot as plt

# Exposure times and mean signals
exposure_times = [0.01, 0.1, 0.5, 1, 5, 10]
mean_signals = [0.27, 0.36, 0.90, 1.77, 8.15, 16.86]


# Plot Mean Signal vs Exposure Time
plt.figure(figsize=(8, 6))
plt.plot(exposure_times, mean_signals, marker='o', linestyle='-', color='b')
plt.title('Mean Dark Current Signal vs Exposure Time')
plt.xlabel('Exposure Time (s)')
plt.ylabel('Mean Signal (ADU)')
plt.grid(True)
plt.show()

from scipy import stats

#linear regression to find the slope (dark current)
slope, intercept, r_value, p_value, std_err = stats.linregress(exposure_times, mean_signals)

#Data vs Linear Fit
plt.figure(figsize=(8, 6))
plt.plot(exposure_times, mean_signals, 'o', label='Data', color='b')
plt.plot(exposure_times, slope * np.array(exposure_times) + intercept, 'r-', label=f'Fit: y = {slope:.2f}x + {intercept:.2f}')
plt.title("Mean Signal vs Exposure Time with Linear Fit")
plt.xlabel("Exposure Time (s)")
plt.ylabel("Mean Signal (ADU)")
plt.legend()
plt.grid(True)
plt.show()

# Dark current is represented by the slope (in ADU per second)
print(f"Dark Current: {slope:.2f} ADU/s with uncertainty of {std_err:.2f} ADU/s")


import pandas as pd

df = pd.DataFrame({
    'Exposure Time (s)': exposure_times,
    'Mean Signal (ADU)': mean_signals
})

df
# Out:
# Dark Current: 1.66 ADU/s with uncertainty of 0.02 ADU/s
#    Exposure Time (s)  Mean Signal (ADU)
# 0               0.01               0.27
# 1               0.10               0.36
# 2               0.50               0.90
# 3               1.00               1.77
# 4               5.00               8.15
# 5              10.00              16.86

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
#
# ## 2.2.2 Read Noise (Currently all over saturated, need to retake)
#
# ### Objective:
# - Analyze a stack of flat frames to measure the read noise.

# %%
flat_files_directory = r'C:\Users\levig\Downloads\FlatFrames'
flat_files = glob(os.path.join(flat_files_directory, '*.raw'))
shape = (1616, 1240)  
for flat_file in flat_files:
    raw_to_fits(flat_file, shape=shape)
    print(f"Converted {flat_file} to FITS format.")

# %%
import numpy as np
from astropy.io import fits
import os

# Directory where your flat frames are stored
flat_frames_directory = r'C:\Users\levig\Downloads\FlatFrames'

# List of exposure times in microseconds (1000 µs = 1 ms)
exposure_times = ["1", "5", "10", "50", "100"]  # Corresponding to 1ms, 5ms, 10ms, 50ms, 100ms

# Initialize a dictionary to store FITS data
flat_frames = {}

# Load flat frames for each exposure time based on the file naming format
for exp_time in exposure_times:
    fits_data_list = []
    
    # Loop over the 5 files for each exposure time (Flat<exp_time>kus_<i>.fits)
    for i in range(1, 6):
        fits_filename = f'Flat{exp_time}kus_{i}.fits'
        fits_file_path = os.path.join(flat_frames_directory, fits_filename)
        
        # Check if the file exists
        if os.path.exists(fits_file_path):
            # Load the FITS file and append to the list
            fits_data_list.append(fits.getdata(fits_file_path))
            print(f"Loaded {fits_filename}")
        else:
            print(f"File not found: {fits_file_path}")
    
    # Store the list of FITS data in the dictionary
    flat_frames[f"{exp_time}us"] = fits_data_list
# Out:
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat1kus_1.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat1kus_2.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat1kus_3.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat1kus_4.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat1kus_5.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat5kus_1.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat5kus_2.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat5kus_3.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat5kus_4.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat5kus_5.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat10kus_1.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat10kus_2.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat10kus_3.fits
# File not found: C:\Users\levig\Downloads\FlatFrames\Flat10kus_4.fits
# ...

# %%
# Initialize a dictionary to store the mean and standard deviation for each exposure time
mean_flat_frames = {}
std_flat_frames = {}

# Loop over the exposure times
for exp_time in exposure_times:
    # Stack flat frames for the current exposure time
    flat_stack = np.array(flat_frames[f"{exp_time}us"])

    # Step 1: Calculate the mean flat frame for the current exposure time
    mean_flat_frames[exp_time] = np.mean(flat_stack, axis=0)

    # Step 2: Calculate the standard deviation across the flat frames (this gives the noise)
    std_flat_frames[exp_time] = np.std(flat_stack, axis=0)

# Print confirmation that the calculations are done
print("Mean and standard deviation calculated for all exposure times.")
# Out:
# Mean and standard deviation calculated for all exposure times.

# %%
import matplotlib.pyplot as plt

# Visualize corrected flat frames and standard deviation (read noise)
for exp_time in exposure_times:
    # Convert the exp_time string (e.g., '1000us') to an integer
    exp_time_int = int(exp_time.replace('us', ''))  # Convert '1000us' to 1000
    
    # Visualize the mean flat frame
    plt.figure(figsize=(8, 6))
    plt.imshow(mean_flat_frames[exp_time], cmap='gray')
    plt.colorbar(label=f'Mean Flat Frame {exp_time_int / 1000} ms (ADU)')
    plt.title(f'Mean Flat Frame {exp_time_int / 1000} ms')
    plt.show()

    # Visualize the standard deviation (read noise)
    plt.figure(figsize=(8, 6))
    plt.imshow(std_flat_frames[exp_time], cmap='inferno')
    plt.colorbar(label=f'Standard Deviation {exp_time_int / 1000} ms (ADU)')
    plt.title(f'Read Noise {exp_time_int / 1000} ms (Standard Deviation)')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8936\1651760106.py in <module>
#       8     # Visualize the mean flat frame
#       9     plt.figure(figsize=(8, 6))
# ---> 10     plt.imshow(mean_flat_frames[exp_time], cmap='gray')
#      11     plt.colorbar(label=f'Mean Flat Frame {exp_time_int / 1000} ms (ADU)')
#      12     plt.title(f'Mean Flat Frame {exp_time_int / 1000} ms')
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
# Initialize a dictionary to store the RMS read noise for each exposure time
rms_read_noise = {}

# Calculate RMS read noise for each exposure time
for exp_time in exposure_times:
    # Convert the exp_time string (e.g., '1000us') to an integer
    exp_time_int = int(exp_time.replace('us', ''))  # Convert '1000us' to 1000
    
    # Calculate the RMS read noise
    rms_read_noise[exp_time] = np.sqrt(np.mean(std_flat_frames[exp_time] ** 2))
    print(f"Read Noise (RMS) for {exp_time_int / 1000} ms: {rms_read_noise[exp_time]:.2f} ADU")

# Print the calculated read noise for each exposure time
print("Read Noise (RMS) for all exposure times:", rms_read_noise)
# Out:
# Read Noise (RMS) for 0.001 ms: nan ADU
# Read Noise (RMS) for 0.005 ms: nan ADU
# Read Noise (RMS) for 0.01 ms: nan ADU
# Read Noise (RMS) for 0.05 ms: nan ADU
# Read Noise (RMS) for 0.1 ms: nan ADU
# Read Noise (RMS) for all exposure times: {'1': nan, '5': nan, '10': nan, '50': nan, '100': nan}

# %%
# Manually check the standard deviation of one set of flat frames
flat_1ms_data = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]

# Stack the images and calculate the standard deviation
stacked_flat_1ms = np.stack(flat_1ms_data, axis=0)
std_flat_1ms = np.std(stacked_flat_1ms, axis=0)

# Visualize the standard deviation for 1ms flat frames
plt.figure(figsize=(8, 6))
plt.imshow(std_flat_1ms, cmap='inferno')
plt.colorbar(label='Standard Deviation (ADU)')
plt.title('Standard Deviation for 1 ms Flat Frames')
plt.show()

# Calculate and print the mean of the standard deviation
mean_std_flat_1ms = np.mean(std_flat_1ms)
print(f"Mean Standard Deviation for 1 ms Flat Frames: {mean_std_flat_1ms:.4f} ADU")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8936\2407471481.py in <module>
#       1 # Manually check the standard deviation of one set of flat frames
# ----> 2 flat_1ms_data = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]
#       3
#       4 # Stack the images and calculate the standard deviation
#       5 stacked_flat_1ms = np.stack(flat_1ms_data, axis=0)
#
# ~\AppData\Local\Temp\ipykernel_8936\2407471481.py in <listcomp>(.0)
#       1 # Manually check the standard deviation of one set of flat frames
# ----> 2 flat_1ms_data = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]
#       3
#       4 # Stack the images and calculate the standard deviation
#       5 stacked_flat_1ms = np.stack(flat_1ms_data, axis=0)
#
# ...

# %%
std_flat_frames = {}

# Loop over each exposure time to recalculate the standard deviation
for exp_time in exposure_times:
    flat_data_list = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]
    stacked_flat_data = np.stack(flat_data_list, axis=0)
    std_flat_frames[exp_time] = np.std(stacked_flat_data, axis=0)

# Recalculate the RMS read noise after verifying the standard deviation
rms_read_noise = {}

for exp_time in exposure_times:
    rms_read_noise[exp_time] = np.sqrt(np.mean(std_flat_frames[exp_time] ** 2))
    print(f"Read Noise (RMS) for {exp_time} ms: {rms_read_noise[exp_time]:.2f} ADU")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8936\3231937893.py in <module>
#       3 # Loop over each exposure time to recalculate the standard deviation
#       4 for exp_time in exposure_times:
# ----> 5     flat_data_list = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]
#       6     stacked_flat_data = np.stack(flat_data_list, axis=0)
#       7     std_flat_frames[exp_time] = np.std(stacked_flat_data, axis=0)
#
# ~\AppData\Local\Temp\ipykernel_8936\3231937893.py in <listcomp>(.0)
#       3 # Loop over each exposure time to recalculate the standard deviation
#       4 for exp_time in exposure_times:
# ----> 5     flat_data_list = [fits.getdata(os.path.join(flat_frames_directory, f'Flat1kus_{i}.fits')) for i in range(1, 6)]
#       6     stacked_flat_data = np.stack(flat_data_list, axis=0)
# ...

# %% [markdown]
# # 2.3 Experiment: Astronomical Measurements

# %% [markdown]
# ## 2.3.1 Photometry
# ### Objective:
# - Measure the flux and flux uncertainty of Jupiter-sim’s red spot. Determine the signal-to-noise ratio on Jupiter-sim’s red spot in a 1 second integration

# %% [markdown]
# ### Here are some pictures that we were able to take of Jupiter with our setup

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Path to your JPEG files
image_path_1 = r'C:\Users\levig\Downloads\Jupiter setup1 (1).jpeg'
image_path_2 = r'C:\Users\levig\Downloads\Jupiter setup1 (3).jpeg'

# Open the images using PIL and convert to grayscale
image1 = Image.open(image_path_1).convert('L')  # 'L' mode is for grayscale
image2 = Image.open(image_path_2).convert('L')

# Convert images to numpy arrays for manipulation
image1_np = np.array(image1)
image2_np = np.array(image2)

# Create a subplot with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # Adjust figsize as needed

# Display the first grayscale image
axes[0].imshow(image1_np, cmap='gray')
axes[0].axis('off')  # Turn off axis labels for image 1
axes[0].set_title("Jupiter Image 1")

# Display the second grayscale image
axes[1].imshow(image2_np, cmap='gray')
axes[1].axis('off')  # Turn off axis labels for image 2
axes[1].set_title("Jupiter Image 2")

# Show the images
plt.show()

# %%
Jupiter_files_directory = r'C:\Users\levig\Downloads\JupiterFits'
Jupiter_files = glob(os.path.join(Jupiter_files_directory, '*.raw'))
shape = (1616, 1240)  
for Jupiter_file in Jupiter_files:
    raw_to_fits(Jupiter_file, shape=shape)
    print(f"Converted {Jupiter_file} to FITS format.")
# Out:
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (1).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (10).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (2).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (3).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (4).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (5).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (6).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (7).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (8).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\Jupiter (9).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\JupiterDark (1).raw to FITS format.
# Converted C:\Users\levig\Downloads\JupiterFits\JupiterDark (10).raw to FITS format.
# ...

# %%
import matplotlib.pyplot as plt
from astropy.io import fits

# Path to your FITS file
fits_file = r'C:\Users\levig\Downloads\JupiterFits\Jupiter (1).fits'

# Open the FITS file
with fits.open(fits_file) as hdul:
    image_data = hdul[0].data

# Display the image using matplotlib
plt.imshow(image_data, cmap='gray')
plt.colorbar()
plt.title('Image from FITS file')
plt.show()
